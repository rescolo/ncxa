# %%
import geojson

# %% [markdown]
# $ git clone https://github.com/mapbox/togeojson.git
# $ cd togeojson
# Install it with
# $ sudo npm install --save togeojson.

# %%
# %%bash
# togeojson kml/001_alto-de-boqueron-san-cristobal-la-estrella.kml >  001_alto-de-boqueron-san-cristobal-la-estrella.geojson

# %%
f=open('001_alto-de-boqueron-san-cristobal-la-estrella.geojson','r')
a=geojson.load(f)

# %%
len(a["features"])
# Out:
# 2

# %%
a["features"][0]
# Out:
# {"geometry": {"coordinates": [-75.63559, 6.164015, 1718], "type": "Point"}, "properties": {"description": "<table width=\"400\" style=\"color:#666\"><tr><td colspan=\"2\" align=\"left\"><a href=\"http://www.wikiloc.com\"><img src=\"http://sc.wklcdn.com/wikiloc/images/wikiloc.png\" alt=\"Wikiloc\"></a></td></tr><tr><td colspan=\"2\"><font style=\"font-size:14pt;color:#2B60DE\"><a href=\"http://www.wikiloc.com/wikiloc/view.do?id=10382496\">ALTO DE BOQUERON - SAN CRISTOBAL - LA ESTRELLA</a></font><br/>near El Tambo, Departamento de Antioquia (Republic of Colombia) by <a style=\"color:#2B60DE\" href=\"http://www.wikiloc.com/wikiloc/user.do?id=472831\">Oscar Upegui</a></td></tr><tr><td colspan=\"2\"><a href=\"http://www.wikiloc.com/wikiloc/view.do?id=10382496\"><img width=\"400\" src=\"http://sc.wklcdn.com/image_15/472831/10382496/elevProfile.png\" alt=\"Elevation Profile\"/></a></td></tr><tr><td width=\"40\"><img src=\"http://s2.wklcdn.com/wikiloc/images/pictograms/2.png\" alt=\"\"/></td
# ...

# %%
a["features"][1]
# Out:
# {"geometry": {"coordinates": [[-75.660447, 6.324131, 2521], [-75.659937, 6.323278, 2497], [-75.660039, 6.323045, 2486], [-75.659878, 6.322968, 2479], [-75.659508, 6.323368, 2469], [-75.659009, 6.322806, 2452], [-75.658521, 6.321334, 2416], [-75.658598, 6.320993, 2411], [-75.658434, 6.319644, 2385], [-75.658217, 6.319054, 2380], [-75.6579, 6.318906, 2368], [-75.657543, 6.318295, 2357], [-75.657558, 6.317617, 2348], [-75.657306, 6.316582, 2325], [-75.657536, 6.314979, 2297], [-75.657409, 6.314278, 2284], [-75.656575, 6.313225, 2264], [-75.655948, 6.312859, 2259], [-75.656208, 6.312344, 2262], [-75.656538, 6.31102, 2236], [-75.656209, 6.309779, 2213], [-75.655581, 6.308862, 2196], [-75.655526, 6.307816, 2186], [-75.655091, 6.306746, 2173], [-75.655337, 6.305586, 2164], [-75.655029, 6.305166, 2149], [-75.65453, 6.304915, 2146], [-75.654469, 6.304722, 2141], [-75.654719, 6.303933, 2134], [-75.65452, 6.303155, 2119], [-75.654601, 6.302811, 2113], [-75.654773, 6.302686, 2109], [-75.654686, 
# ...
